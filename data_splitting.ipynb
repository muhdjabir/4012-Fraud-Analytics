# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %% [markdown]
# <h2> Reading in all the data

# %%
orig_train = pd.read_csv("train_original.csv", sep="|")
orig_train.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0           5                    1054       54.70              7
# 1           3                     108       27.36              5
# 2           3                    1516       62.16              3
# 3           6                    1791       92.31              8
# 4           5                     430       81.53              3
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         0                      3                   0.027514
# 1                         2                      4                   0.129630
# 2                        10                      5                   0.008575
# 3                         4                      4                   0.016192
# 4                         7                      2                   0.062791
#
#    valuePerSecond  lineItemVoidsPerPosition  fraud
# 0        0.051898                  0.241379      0
# 1        0.253333                  0.357143      0
# 2        0.041003                  0.230769      0
# 3        0.051541                  0.275862      0
# 4        0.189605                  0.111111      0

# %%
orig_test = pd.read_csv("test_original.csv", sep="|")
orig_test.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0           4                     467       88.48              4
# 1           3                    1004       58.99              7
# 2           1                     162       14.00              4
# 3           5                     532       84.79              9
# 4           5                     890       42.16              4
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         8                      4                   0.014989
# 1                         6                      1                   0.026892
# 2                         5                      4                   0.006173
# 3                         3                      4                   0.026316
# 4                         0                      0                   0.021348
#
#    valuePerSecond  lineItemVoidsPerPosition
# 0        0.189465                  0.571429
# 1        0.058755                  0.259259
# 2        0.086420                  4.000000
# 3        0.159380                  0.642857
# 4        0.047371                  0.210526

# %%
labels = pd.read_csv("labels.csv")
labels.head()
# Out:
#    fraud
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %% [markdown]
# <h2> Handling the data

# %%
# Combining the labels with the test data
orig_test["fraud"] = labels["fraud"]
orig_test.head()
# Out:
#    trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0           4                     467       88.48              4
# 1           3                    1004       58.99              7
# 2           1                     162       14.00              4
# 3           5                     532       84.79              9
# 4           5                     890       42.16              4
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         8                      4                   0.014989
# 1                         6                      1                   0.026892
# 2                         5                      4                   0.006173
# 3                         3                      4                   0.026316
# 4                         0                      0                   0.021348
#
#    valuePerSecond  lineItemVoidsPerPosition  fraud
# 0        0.189465                  0.571429      0
# 1        0.058755                  0.259259      0
# 2        0.086420                  4.000000      0
# 3        0.159380                  0.642857      0
# 4        0.047371                  0.210526      0

# %%
all_data = pd.concat([orig_train, orig_test], ignore_index=True)
all_data
# Out:
#         trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0                5                    1054       54.70              7
# 1                3                     108       27.36              5
# 2                3                    1516       62.16              3
# 3                6                    1791       92.31              8
# 4                5                     430       81.53              3
# ...            ...                     ...         ...            ...
# 499995           4                     783       59.10              2
# 499996           1                     278       98.90              9
# 499997           3                     300        5.41              6
# 499998           2                    1524       33.97              2
# 499999           3                    1456       56.97             11
#
#         scansWithoutRegistration  quantityModifications  \
# 0                              0                      3
# 1                              2                      4
# 2                             10                      5
# 3                              4                      4
# 4                              7                      2
# ...                          ...                    ...
# 499995                         2                      0
# 499996                         5                      4
# 499997                         6                      4
# 499998                         5                      3
# 499999                         7                      2
#
#         scannedLineItemsPerSecond  valuePerSecond  lineItemVoidsPerPosition  \
# 0                        0.027514        0.051898                  0.241379
# 1                        0.129630        0.253333                  0.357143
# 2                        0.008575        0.041003                  0.230769
# 3                        0.016192        0.051541                  0.275862
# 4                        0.062791        0.189605                  0.111111
# ...                           ...             ...                       ...
# 499995                   0.012771        0.075479                  0.200000
# 499996                   0.050360        0.355755                  0.642857
# 499997                   0.030000        0.018033                  0.666667
# 499998                   0.005906        0.022290                  0.222222
# 499999                   0.019231        0.039128                  0.392857
#
#         fraud
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 499995      0
# 499996      0
# 499997      0
# 499998      0
# 499999      0
#
# [500000 rows x 10 columns]

# %% [markdown]
# <h2> Splitting of the datasets

# %%
train_dataset, test_dataset = train_test_split(all_data, test_size=0.3)
test_dataset, validate_dataset = train_test_split(test_dataset, test_size=1/3)

# %%
train_dataset.to_csv("train.csv", index=False)
# Out:
#         trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 440459           2                     192       91.51              8
# 76004            6                    1087       54.47             11
# 378927           6                    1099       39.99              9
# 120034           3                    1222       27.85              5
# 130908           1                    1573       37.50              1
# ...            ...                     ...         ...            ...
# 299816           5                     972        5.88             10
# 232600           3                     810       86.01              8
# 12290            6                     422        7.86              6
# 401050           1                     352       43.53              3
# 454120           2                      14       76.91              6
#
#         scansWithoutRegistration  quantityModifications  \
# 440459                         5                      1
# 76004                          7                      5
# 378927                         9                      2
# 120034                         7                      3
# 130908                         6                      4
# ...                          ...                    ...
# 299816                         6                      4
# 232600                         4                      4
# 12290                          7                      2
# 401050                        10                      0
# 454120                         2                      1
#
#         scannedLineItemsPerSecond  valuePerSecond  lineItemVoidsPerPosition  \
# 440459                   0.078125        0.476615                  0.533333
# 76004                    0.022079        0.050110                  0.458333
# 378927                   0.009099        0.036388                  0.900000
# 120034                   0.000818        0.022791                  5.000000
# 130908                   0.006357        0.023840                  0.100000
# ...                           ...             ...                       ...
# 299816                   0.001029        0.006049                 10.000000
# 232600                   0.033333        0.106185                  0.296296
# 12290                    0.052133        0.018626                  0.272727
# 401050                   0.011364        0.123665                  0.750000
# 454120                   0.428571        5.493571                  1.000000
#
#         fraud
# 440459      0
# 76004       0
# 378927      0
# 120034      0
# 130908      0
# ...       ...
# 299816      0
# 232600      0
# 12290       0
# 401050      0
# 454120      0
#
# [50000 rows x 10 columns]

# %%
validate_dataset = pd.read_csv("validate.csv")
validate_dataset
# Out:
#        trustLevel  totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0               4                     776       46.69             11
# 1               2                     778       23.21              4
# 2               4                    1093        6.75              1
# 3               5                     913       11.43              0
# 4               4                    1804       49.96             10
# ...           ...                     ...         ...            ...
# 49995           5                     557       53.20              7
# 49996           2                    1257       38.48              8
# 49997           5                     342       81.42              4
# 49998           1                    1767       57.70              1
# 49999           3                    1177       49.04              9
#
#        scansWithoutRegistration  quantityModifications  \
# 0                             9                      1
# 1                             9                      0
# 2                             6                      4
# 3                             9                      1
# 4                             8                      3
# ...                         ...                    ...
# 49995                         0                      1
# 49996                         6                      4
# 49997                         8                      1
# 49998                         8                      5
# 49999                         4                      3
#
#        scannedLineItemsPerSecond  valuePerSecond  lineItemVoidsPerPosition  \
# 0                       0.027062        0.060168                  0.523810
# 1                       0.010283        0.029833                  0.500000
# 2                       0.018298        0.006176                  0.050000
# 3                       0.016429        0.012519                  0.000000
# 4                       0.004989        0.027694                  1.111111
# ...                          ...             ...                       ...
# 49995                   0.005386        0.095512                  2.333333
# 49996                   0.023866        0.030613                  0.266667
# 49997                   0.029240        0.238070                  0.400000
# 49998                   0.014148        0.032654                  0.040000
# 49999                   0.008496        0.041665                  0.900000
#
#        fraud
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 49995      0
# 49996      1
# 49997      0
# 49998      1
# 49999      0
#
# [50000 rows x 10 columns]
